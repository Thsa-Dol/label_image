# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.48 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.2/107.7 GB disk)

# %%
# Run inference on an image with YOLOv8n
# !yolo predict model=yolov8n.pt source='https://ultralytics.com/images/zidane.jpg'
# Out:
# ...
# 100% 6.25M/6.25M [00:00<00:00, 75.9MB/s]
# Ultralytics YOLOv8.2.48 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# ...
# 100% 165k/165k [00:00<00:00, 4.90MB/s]
# image 1/1 /content/zidane.jpg: 384x640 2 persons, 1 tie, 219.1ms
# Speed: 14.5ms preprocess, 219.1ms inference, 27.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# Train YOLOv8n on COCO8 for 3 epochs
# !yolo train model=/content/runs/detect/train2/weights/last.pt data=/content/drive/MyDrive/coco8.yaml epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.2.48 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !yolo predict model=/content/runs/detect/train3/weights/best.pt source='/content/drive/MyDrive/chomeo_test.jpg'
# Out:
# Ultralytics YOLOv8.2.48 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/drive/MyDrive/chomeo_test.jpg: 640x640 3 cats, 252.5ms
# Speed: 10.6ms preprocess, 252.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model=/content/runs/detect/train3/weights/best.pt source='/content/drive/MyDrive/cho2.jpg'
# Out:
# Ultralytics YOLOv8.2.48 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/drive/MyDrive/cho2.jpg: 480x640 1 dog, 159.2ms
# Speed: 5.4ms preprocess, 159.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model=/content/runs/detect/train3/weights/best.pt source='/content/drive/MyDrive/meo1.jpg'
# Out:
# Ultralytics YOLOv8.2.48 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/drive/MyDrive/meo1.jpg: 448x640 1 cat, 149.8ms
# Speed: 4.9ms preprocess, 149.8ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !tar -cvf runs.tar /content/runs
# Out:
# tar: Removing leading `/' from member names
# /content/runs/
# /content/runs/detect/
# /content/runs/detect/train3/
# /content/runs/detect/train3/train_batch2.jpg
# /content/runs/detect/train3/val_batch1_pred.jpg
# /content/runs/detect/train3/train_batch0.jpg
# /content/runs/detect/train3/events.out.tfevents.1720072999.6035cdac4cdf.22544.0
# /content/runs/detect/train3/confusion_matrix_normalized.png
# /content/runs/detect/train3/results.png
# /content/runs/detect/train3/val_batch0_pred.jpg
# /content/runs/detect/train3/val_batch0_labels.jpg
# /content/runs/detect/train3/results.csv
# /content/runs/detect/train3/weights/
# /content/runs/detect/train3/weights/best.pt
# /content/runs/detect/train3/weights/last.pt
# /content/runs/detect/train3/labels_correlogram.jpg
# /content/runs/detect/train3/train_batch120.jpg
# /content/runs/detect/train3/train_batch1.jpg
# /content/runs/detect/train3/F1_curve.png
# /content/runs/detect/train3/R_curve.png
# /content/runs/detect/train3/labels.jpg
# ...
