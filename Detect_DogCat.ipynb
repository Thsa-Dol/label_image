# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.48 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.2/107.7 GB disk)

# %%
# Run inference on an image with YOLOv8n
# !yolo predict model=yolov8n.pt source='https://ultralytics.com/images/zidane.jpg'
# Out:
# ...
# 100% 6.25M/6.25M [00:00<00:00, 73.6MB/s]
# Ultralytics YOLOv8.2.48 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# ...
# 100% 165k/165k [00:00<00:00, 5.10MB/s]
# image 1/1 /content/zidane.jpg: 384x640 2 persons, 1 tie, 269.2ms
# Speed: 19.8ms preprocess, 269.2ms inference, 33.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !tar -xvf /content/dogcat.tar
# Out:
# tar: Removing leading `/' from member names
# /
# data_config.yaml
# images/
# images/train/
# images/train/956200_dataset 2024-06-28 09-45-47_ch013.jpg
# images/train/956200_dataset 2024-06-28 09-45-47_cho1.jpg
# images/train/956200_dataset 2024-06-28 09-45-47_cho10.jpg
# images/train/956200_dataset 2024-06-28 09-45-47_cho11.jpg
# images/train/956200_dataset 2024-06-28 09-45-47_cho12.jpg
# images/train/956200_dataset 2024-06-28 09-45-47_cho14.jpg
# images/train/956200_dataset 2024-06-28 09-45-47_cho15.jpg
# images/train/956200_dataset 2024-06-28 09-45-47_cho16.jpg
# images/train/956200_dataset 2024-06-28 09-45-47_cho17.jpg
# images/train/956200_dataset 2024-06-28 09-45-47_cho18.jpg
# images/train/956200_dataset 2024-06-28 09-45-47_cho19.jpg
# images/train/956200_dataset 2024-06-28 09-45-47_cho2.jpg
# images/train/956200_dataset 2024-06-28 09-45-47_cho20.jpg
# images/train/956200_dataset 2024-06-28 09-45-47_cho3.jpg
# images/train/956200_dataset 2024-06-28 09-45-47_cho4.jpg
# ...

# %%
# Train YOLOv8n on COCO8 for 3 epochs
# !yolo train model=/content/runs/detect/train2/weights/last.pt data=/content/coco8.yaml epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.2.48 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !yolo predict model=/content/runs/detect/train4/weights/best.pt source='/content/chomeo.jpg'
# Out:
# Ultralytics YOLOv8.2.48 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/chomeo.jpg: 640x640 1 dog, 1 cat, 282.9ms
# Speed: 10.0ms preprocess, 282.9ms inference, 6.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
